# %% [markdown]
# <a href="https://colab.research.google.com/github/kartik815/Amazon-ML-Challenge-2026/blob/main/notebooks/01_Environment_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/kartik815/Amazon-ML-Challenge-2026
# Out:
# Cloning into 'Amazon-ML-Challenge-2026'...
# fatal: could not read Username for 'https://github.com': No such device or address
